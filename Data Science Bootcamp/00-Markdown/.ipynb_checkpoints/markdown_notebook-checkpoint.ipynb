# %% [markdown]
# Inline code: `code`
# Code block:
# ```
# print("Hello Markdown")
# ```
# ## Links
# [Google](https://google.com)
# ## Images
# ![Alt text](image.png)
# ## Blockquote
# > This is a quote.
# ## Horizontal Rule
# ---
# ## Tables
# | Name | Age |
# |------|-----|
# | John | 24 |
# | Ana  | 22 |
# ## Task List
# - [x] Done
# - [ ] Not Done
# ## Inline HTML
# This is bold using HTML
