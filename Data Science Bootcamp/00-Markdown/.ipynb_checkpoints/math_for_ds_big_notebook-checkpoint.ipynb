# %% [markdown]
# # Math for Data Science – Mega NotebookThis notebook covers key math topics: Probability, Statistics, Linear Algebra, Calculus, Optimization, Distance Metrics, Feature Engineering, Information Theory, Time Series, Linear Models.

# %% [markdown]
# ## ProbabilityDefinitions, conditional probability, Bayes theorem.### Bayes Theorem$$P(A|B)=\frac{P(B|A)P(A)}{P(B)}$$

# %% [markdown]
# ## StatisticsConfidence intervals, hypothesis testing, sampling, CLT.

# %% [markdown]
# ## Linear AlgebraVectors, matrices, dot product, eigenvalues, SVD.

# %% [markdown]
# ## CalculusDerivatives, gradients, chain rule, partial derivatives.

# %% [markdown]
# ## OptimizationGradient descent, loss functions, convexity.

# %% [markdown]
# ## Distance & SimilarityEuclidean, Manhattan, Cosine.

# %% [markdown]
# ## Feature EngineeringScaling, encoding, PCA.

# %% [markdown]
# ## Information TheoryEntropy, cross-entropy, KL divergence.

# %% [markdown]
# ## Time SeriesAutocorrelation, ARIMA basics.

# %% [markdown]
# ## Linear ModelsOLS, R2, bias-variance.

# %%
import numpy as npprint('Math DS Notebook Loaded')
