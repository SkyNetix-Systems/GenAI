# %% [markdown]
# # Markdown Cheatsheet
# ## Headings
# # H1
# ## H2
# ### H3
# #### H4
# ##### H5
# ###### H6
# ## Bold & Italic
# **Bold**
# *Italic*
# ***Bold + Italic***
# ## Lists
# ### Unordered
# - Item 1
# - Item 2
# - Subitem
# ### Ordered
# 1. Item 1
# 2. Item 2
# 10. Subitem
# ## Links
# [Google](https://google.com)
# ## Tables
# | Name | Age |
# |------|-----|
# | John | 24 |
# | Ana | 22 |
# ## Task List
# - [x] Done
# - [ ] Not Done
# ## Inline HTML
# This is bold using HTML
