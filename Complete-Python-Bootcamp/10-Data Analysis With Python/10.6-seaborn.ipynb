# %% [markdown]
# #### Data Visualization With Seaborn
# Seaborn is a Python visualization library based on Matplotlib that provides a high-level interface for drawing attractive and informative statistical graphics. Seaborn helps in creating complex visualizations with just a few lines of code. In this lesson, we will cover the basics of Seaborn, including creating various types of plots and customizing them.

# %%
pip install seaborn
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
import seaborn as sns

# %%
### Basic Plotting With Seaborn
# Seaborn comes with a few built-in sample datasets for quick practice.
# tips is one of the most famous ones — it contains restaurant tipping data.

tips=sns.load_dataset('tips')
tips.head(10)
# Out:
#    total_bill   tip     sex smoker  day    time  size
# 0       16.99  1.01  Female     No  Sun  Dinner     2
# 1       10.34  1.66    Male     No  Sun  Dinner     3
# 2       21.01  3.50    Male     No  Sun  Dinner     3
# 3       23.68  3.31    Male     No  Sun  Dinner     2
# 4       24.59  3.61  Female     No  Sun  Dinner     4
# 5       25.29  4.71    Male     No  Sun  Dinner     4
# 6        8.77  2.00    Male     No  Sun  Dinner     2
# 7       26.88  3.12    Male     No  Sun  Dinner     4
# 8       15.04  1.96    Male     No  Sun  Dinner     2
# 9       14.78  3.23    Male     No  Sun  Dinner     2

# %%
##create a scatter plot
# Seaborn is built on top of Matplotlib
# So Seaborn does the fancy styling + layout…
# and then hands the figure over to Matplotlib to display.

import matplotlib.pyplot as plt

# sns.scatterplot(x='total_bill',y='tip',data=tips)
sns.scatterplot(x='total_bill', y='tip', hue='sex', data=tips)
plt.title("Scatter Plot of Total Bill vs Tip")
plt.show()

# %%
## Line Plot

sns.lineplot(x='size',y='total_bill',data=tips)
plt.title("Line Plot of Total bill by size")
plt.show()

# %%
## Categorical Plots
## BAr Plot
sns.barplot(x='day',y='total_bill',data=tips)
plt.title('Bar Plot of Total Bill By Day')
plt.show()

# %% [markdown]
# 🔥 Those vertical lines = Confidence Intervals (CI)
#
# In Seaborn barplot, each bar shows:
#
# 👉 the mean value (average total_bill for that day)
# 👉 and the black vertical line is the 95% confidence interval around that mean

# %%
## Box Plot
sns.boxplot(x="day",y='total_bill',data=tips)
# Out:
# <Axes: xlabel='day', ylabel='total_bill'>

# %% [markdown]
# 📦 Boxplot Components (super clear version)
#
# 1️⃣ Median (middle line in the box)
#
# The thick horizontal line inside the box
#
# Represents the middle bill amount
#
# 50% of bills are below, 50% above
#
# 2️⃣ Box = IQR (Interquartile Range)
#
# The box edges represent:
#
# Bottom of box → Q1 (25th percentile)
#
# Top of box → Q3 (75th percentile)
#
# This shows the middle 50% of values.
#
# Basically where most customers’ bills fall.
#
# 3️⃣ Whiskers
#
# The vertical lines extending from the box show:
#
# Upper whisker → max value within 1.5 × IQR
#
# Lower whisker → min value within 1.5 × IQR
#
# Whiskers show normal-ish range.
#
# 4️⃣ Outliers (white dots 🔵🟡)
#
# Those little circles above the whiskers?
#
# 👉 Bills that are unusually high
# (way above what customers normally spend)
#
# Seaborn marks any point beyond 1.5 × IQR as an outlier.
#
# Your plot shows multiple outliers especially on Sat and Sun, meaning:

# %%
## Violin Plot

sns.violinplot(x='day',y='total_bill',data=tips)
# Out:
# <Axes: xlabel='day', ylabel='total_bill'>

# %%
### Histograms
sns.histplot(tips['total_bill'],bins=10,kde=True)
# Out:
# <Axes: xlabel='total_bill', ylabel='Count'>

# %%
## KDE Plot
sns.kdeplot(tips['total_bill'],fill=True)
# Out:
# <Axes: xlabel='total_bill', ylabel='Density'>

# %%
# Pairplot
sns.pairplot(tips)

# %%
tips
# Out:
#      total_bill   tip     sex smoker   day    time  size
# 0         16.99  1.01  Female     No   Sun  Dinner     2
# 1         10.34  1.66    Male     No   Sun  Dinner     3
# 2         21.01  3.50    Male     No   Sun  Dinner     3
# 3         23.68  3.31    Male     No   Sun  Dinner     2
# 4         24.59  3.61  Female     No   Sun  Dinner     4
# ..          ...   ...     ...    ...   ...     ...   ...
# 239       29.03  5.92    Male     No   Sat  Dinner     3
# 240       27.18  2.00  Female    Yes   Sat  Dinner     2
# 241       22.67  2.00    Male    Yes   Sat  Dinner     2
# 242       17.82  1.75    Male     No   Sat  Dinner     2
# 243       18.78  3.00  Female     No  Thur  Dinner     2
#
# [244 rows x 7 columns]

# %%
## Heatmap
corr=tips[['total_bill','tip','size']].corr()
corr
# Out:
#             total_bill       tip      size
# total_bill    1.000000  0.675734  0.598315
# tip           0.675734  1.000000  0.489299
# size          0.598315  0.489299  1.000000

# %%
sns.heatmap(corr,annot=True,cmap='coolwarm')
# Out:
# <Axes: >

# %%
import pandas as pd
sales_df=pd.read_csv('sales_data.csv')
sales_df.head()
# Out:
#    Transaction ID        Date Product Category             Product Name  \
# 0           10001  2024-01-01      Electronics            iPhone 14 Pro
# 1           10002  2024-01-02  Home Appliances         Dyson V11 Vacuum
# 2           10003  2024-01-03         Clothing         Levi's 501 Jeans
# 3           10004  2024-01-04            Books        The Da Vinci Code
# 4           10005  2024-01-05  Beauty Products  Neutrogena Skincare Set
#
#    Units Sold  Unit Price  Total Revenue         Region Payment Method
# 0           2      999.99        1999.98  North America    Credit Card
# 1           1      499.99         499.99         Europe         PayPal
# 2           3       69.99         209.97           Asia     Debit Card
# 3           4       15.99          63.96  North America    Credit Card
# 4           1       89.99          89.99         Europe         PayPal

# %%
## Plot total sales by product
plt.figure(figsize=(10,6))
sns.barplot(x='Product Category',y="Total Revenue",data=sales_df,estimator=sum)
plt.title('Total Sales by Product')
plt.xlabel('Product')
plt.ylabel('Total Sales')
plt.show()

# %%
## Plot total sales by Region
plt.figure(figsize=(10,6))
sns.barplot(x='Region',y="Total Revenue",data=sales_df,estimator=sum)
plt.title('Total Sales by Region')
plt.xlabel('Region')
plt.ylabel('Total Sales')
plt.show()
