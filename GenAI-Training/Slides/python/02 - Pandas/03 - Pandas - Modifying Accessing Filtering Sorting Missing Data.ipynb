# %% [markdown]
# ##  Modifying Data: Adding and Dropping Columns and Rows

# %%
import pandas as pd

# Sample DataFrame
data = {
    'Name': ['Alice', 'Bob', 'Charlie'],
    'Age': [25, 30, 35]
}
df = pd.DataFrame(data)

# %%
df
# Out:
#       Name  Age
# 0    Alice   25
# 1      Bob   30
# 2  Charlie   35

# %%
df['City'] = ['New York', 'Los Angeles', 'Chicago']

# %%
df
# Out:
#       Name  Age         City
# 0    Alice   25     New York
# 1      Bob   30  Los Angeles
# 2  Charlie   35      Chicago

# %%
df['Age Group'] = ['Young' if age < 30 else 'Mature' for age in df['Age']]

# %%
df
# Out:
#       Name  Age         City Age Group
# 0    Alice   25     New York     Young
# 1      Bob   30  Los Angeles    Mature
# 2  Charlie   35      Chicago    Mature

# %%
df = df.drop('Age Group', axis=1)

# %%
df
# Out:
#       Name  Age         City
# 0    Alice   25     New York
# 1      Bob   30  Los Angeles
# 2  Charlie   35      Chicago

# %%
df = df.drop(1)

# %%
df
# Out:
#       Name  Age      City
# 0    Alice   25  New York
# 2  Charlie   35   Chicago

# %%
df_copy = df.copy()

# %%
df_copy
# Out:
#       Name  Age      City
# 0    Alice   25  New York
# 2  Charlie   35   Chicago

# %%
df = df.assign(Discount=[5, 10], Total_Spend=[100, 200])

# %%
df
# Out:
#       Name  Age      City  Discount  Total_Spend
# 0    Alice   25  New York         5          100
# 2  Charlie   35   Chicago        10          200

# %% [markdown]
# ## Accessing Data: Using df.iloc[] and df.loc[]

# %%
import pandas as pd

# Sample DataFrame
data = {
    'Name': ['Alice', 'Bob', 'Charlie', 'David', 'Eva'],
    'Age': [25, 30, 35, 40, 45],
    'City': ['New York', 'Los Angeles', 'Chicago', 'Houston', 'Seattle']
}
df = pd.DataFrame(data)

# %%
df
# Out:
#       Name  Age         City
# 0    Alice   25     New York
# 1      Bob   30  Los Angeles
# 2  Charlie   35      Chicago
# 3    David   40      Houston
# 4      Eva   45      Seattle

# %%
row = df.loc[2]
row
# Out:
# Name    Charlie
# Age          35
# City    Chicago
# Name: 2, dtype: object

# %%
cell = df.loc[3, 'City']
cell
# Out:
# 'Houston'

# %%
subset_rows = df.loc[1:3]
subset_rows
# Out:
#       Name  Age         City
# 1      Bob   30  Los Angeles
# 2  Charlie   35      Chicago
# 3    David   40      Houston

# %%
subset = df.loc[1:4, ['Name', 'City']]
subset
# Out:
#       Name         City
# 1      Bob  Los Angeles
# 2  Charlie      Chicago
# 3    David      Houston
# 4      Eva      Seattle

# %%
mask = df['Age'] > 30
filtered = df.loc[mask].iloc[:, 0]
filtered
# Out:
# 2    Charlie
# 3      David
# 4        Eva
# Name: Name, dtype: object

# %%
df
# Out:
#       Name  Age         City
# 0    Alice   25     New York
# 1      Bob   30  Los Angeles
# 2  Charlie   35      Chicago
# 3    David   40      Houston
# 4      Eva   45      Seattle

# %%
df.iloc[1:4]
# Out:
#       Name  Age         City
# 1      Bob   30  Los Angeles
# 2  Charlie   35      Chicago
# 3    David   40      Houston

# %% [markdown]
# ##  Sampling and Previewing Data: Using df.sample() and df.head()

# %%
import pandas as pd
df = pd.read_csv('model_logs.csv')

# %%
df.head(3)
# Out:
#          Date                                        Prompt  \
# 0  2023-01-01  Generate a creative story about space travel
# 1  2023-01-02        Write a sci-fi short story set in 2050
# 2  2023-01-03   Write a poem about the future of technology
#
#    Response Time (ms)  Tokens Generated
# 0                  62               287
# 1                  45               361
# 2                  33               221

# %%
random_row = df.sample()
random_row
# Out:
#           Date                                          Prompt  \
# 98  2023-04-09  Generate marketing copy for a new tech product
#
#     Response Time (ms)  Tokens Generated
# 98                  77               296

# %%
random_rows = df.sample(n=3)
random_rows
# Out:
#           Date                                    Prompt  Response Time (ms)  \
# 64  2023-03-06  Outline the ethical considerations of AI                  51
# 80  2023-03-22          Explain blockchain for beginners                  90
# 52  2023-02-22   Describe the impact of AI on healthcare                  90
#
#     Tokens Generated
# 64               269
# 80               226
# 52               416

# %%
random_sample = df.sample(n=5, random_state=67)
random_sample
# Out:
#           Date                                        Prompt  \
# 17  2023-01-18  Generate a creative story about space travel
# 24  2023-01-25       Describe the impact of AI on healthcare
# 64  2023-03-06      Outline the ethical considerations of AI
# 93  2023-04-04     Explain quantum computing in simple terms
# 97  2023-04-08   Write a poem about the future of technology
#
#     Response Time (ms)  Tokens Generated
# 17                  61               484
# 24                  97               271
# 64                  51               269
# 93                  97               325
# 97                  38               465

# %%
fraction_sample = df.sample(frac=0.3)
fraction_sample
# Out:
#           Date                                           Prompt  \
# 39  2023-02-09         Outline the ethical considerations of AI
# 68  2023-03-10                 Explain blockchain for beginners
# 10  2023-01-11     Generate a creative story about space travel
# 31  2023-02-01        Explain quantum computing in simple terms
# 37  2023-02-07      Write a poem about the future of technology
# 62  2023-03-04        Explain quantum computing in simple terms
# 36  2023-02-06  Summarize the latest research on climate change
# 91  2023-04-02        Explain quantum computing in simple terms
# 28  2023-01-29    Create a recipe using plant-based ingredients
# 46  2023-02-16          Describe the impact of AI on healthcare
# 35  2023-02-05  Summarize the latest research on climate change
# 33  2023-02-03      Write a poem about the future of technology
# 53  2023-02-23   Generate marketing copy for a new tech product
# 3   2023-01-04        Explain quantum computing in simple terms
# 23  2023-01-24         Outline the ethical considerations of AI
# 66  2023-03-08     Generate a creative story about space travel
# 24  2023-01-25          Describe the impact of AI on healthcare
# 8   2023-01-09   Generate marketing copy for a new tech product
# 26  2023-01-27                 Explain blockchain for beginners
# 76  2023-03-18   Generate marketing copy for a new tech product
# 56  2023-02-26  Summarize the latest research on climate change
# 16  2023-01-17   Generate marketing copy for a new tech product
# 42  2023-02-12         Outline the ethical considerations of AI
# 94  2023-04-05  Summarize the latest research on climate change
# 93  2023-04-04        Explain quantum computing in simple terms
# 22  2023-01-23      Write a poem about the future of technology
# 89  2023-03-31                 Explain blockchain for beginners
# 73  2023-03-15                 Explain blockchain for beginners
# 18  2023-01-19         Outline the ethical considerations of AI
# 41  2023-02-11          Describe the impact of AI on healthcare
#
#     Response Time (ms)  Tokens Generated
# 39                  33               286
# 68                  59               316
# 10                  98               230
# 31                  42               265
# 37                  70               306
# 62                  42               219
# 36                  94               324
# 91                  69               462
# 28                  97               257
# 46                  73               302
# 35                  64               205
# 33                  97               283
# 53                  74               318
# 3                   53               290
# 23                  53               301
# 66                  70               379
# 24                  97               271
# 8                   96               427
# 26                  67               314
# 76                  91               329
# 56                  86               500
# 16                  91               225
# 42                  41               499
# 94                  41               500
# 93                  97               325
# 22                  94               210
# 89                  78               490
# 73                  91               293
# 18                  78               242
# 41                  99               437

# %% [markdown]
# ## Filtering Data: Masks and pandas.Series.between()

# %%
import pandas as pd

# Sample DataFrame
data = {
    'Name': ['Alice', 'Bob', 'Charlie', 'David', 'Eva'],
    'Age': [25, 30, 35, 40, 45],
    'City': ['New York', 'Los Angeles', 'Chicago', 'Houston', 'Miami']
}
df = pd.DataFrame(data)

# %%
df
# Out:
#       Name  Age         City
# 0    Alice   25     New York
# 1      Bob   30  Los Angeles
# 2  Charlie   35      Chicago
# 3    David   40      Houston
# 4      Eva   45        Miami

# %%
mask = df['Age'] > 30

# %%
mask
# Out:
# 0    False
# 1    False
# 2     True
# 3     True
# 4     True
# Name: Age, dtype: bool

# %%
filtered_df = df[mask]
filtered_df
# Out:
#       Name  Age     City
# 2  Charlie   35  Chicago
# 3    David   40  Houston
# 4      Eva   45    Miami

# %%
mask = (df['Age'] > 30) & (df['City'] != 'Houston')
filtered_df = df[mask]
filtered_df
# Out:
#       Name  Age     City
# 2  Charlie   35  Chicago
# 4      Eva   45    Miami

# %%
mask
# Out:
# 0    False
# 1    False
# 2     True
# 3    False
# 4     True
# dtype: bool

# %% [markdown]
# ### pandas.Series.between()

# %%
df
# Out:
#       Name  Age         City
# 0    Alice   25     New York
# 1      Bob   30  Los Angeles
# 2  Charlie   35      Chicago
# 3    David   40      Houston
# 4      Eva   45        Miami

# %%
filtered_df = df[df['Age'].between(30, 40)]
filtered_df
# Out:
#       Name  Age         City
# 1      Bob   30  Los Angeles
# 2  Charlie   35      Chicago
# 3    David   40      Houston

# %%
mask = df['City'].isin(['Chicago', 'Houston'])
filtered_df = df[mask]
filtered_df
# Out:
#       Name  Age     City
# 2  Charlie   35  Chicago
# 3    David   40  Houston

# %% [markdown]
# ## Sorting Data

# %%
import pandas as pd

# Sample DataFrame
data = {
    'Name': ['Alice', 'Bob', 'Charlie', 'David', 'Eva'],
    'Age': [25, 30, 35, 40, 45],
    'City': ['New York', 'Los Angeles', 'Chicago', 'Houston', 'Miami']
}
df = pd.DataFrame(data)

# %%
df
# Out:
#       Name  Age         City
# 0    Alice   25     New York
# 1      Bob   30  Los Angeles
# 2  Charlie   35      Chicago
# 3    David   40      Houston
# 4      Eva   45        Miami

# %%
sorted_df = df.sort_values(by='Age')
sorted_df
# Out:
#       Name  Age         City
# 0    Alice   25     New York
# 1      Bob   30  Los Angeles
# 2  Charlie   35      Chicago
# 3    David   40      Houston
# 4      Eva   45        Miami

# %%
sorted_df = df.sort_values(by='Age', ascending=False)
sorted_df
# Out:
#       Name  Age         City
# 4      Eva   45        Miami
# 3    David   40      Houston
# 2  Charlie   35      Chicago
# 1      Bob   30  Los Angeles
# 0    Alice   25     New York

# %%
sorted_df = df.sort_values(by=['City', 'Age'])
sorted_df
# Out:
#       Name  Age         City
# 2  Charlie   35      Chicago
# 3    David   40      Houston
# 1      Bob   30  Los Angeles
# 4      Eva   45        Miami
# 0    Alice   25     New York

# %%
sorted_df = df.sort_index()
sorted_df
# Out:
#       Name  Age         City
# 0    Alice   25     New York
# 1      Bob   30  Los Angeles
# 2  Charlie   35      Chicago
# 3    David   40      Houston
# 4      Eva   45        Miami

# %%
df
# Out:
#       Name  Age         City
# 0    Alice   25     New York
# 1      Bob   30  Los Angeles
# 2  Charlie   35      Chicago
# 3    David   40      Houston
# 4      Eva   45        Miami

# %%
df.sort_values(by='Age', ascending=False, inplace=True)

# %%
df
# Out:
#       Name  Age         City
# 4      Eva   45        Miami
# 3    David   40      Houston
# 2  Charlie   35      Chicago
# 1      Bob   30  Los Angeles
# 0    Alice   25     New York

# %%
# Example DataFrame: Player leaderboard with names and scores
data = {
    'Player': ['Alice', 'Bob', 'Charlie', 'Diana', 'Eve'],
    'Score': [150, 200, 125, 300, 175]
}
df = pd.DataFrame(data)
df
# Out:
#     Player  Score
# 0    Alice    150
# 1      Bob    200
# 2  Charlie    125
# 3    Diana    300
# 4      Eve    175

# %%
sorted_df = df.sort_values(by='Score', ascending=False).reset_index(drop=True)
sorted_df['Rank'] = sorted_df.index + 1
sorted_df
# Out:
#     Player  Score  Rank
# 0    Diana    300     1
# 1      Bob    200     2
# 2      Eve    175     3
# 3    Alice    150     4
# 4  Charlie    125     5

# %% [markdown]
# ## Handling Missing Data

# %%
import pandas as pd
# Sample DataFrame with missing values
data = {
    'Name': ['Alice', 'Bob', 'Charlie', 'Diana'],
    'Age': [25, None, 35, 40],
    'City': ['New York', 'Los Angeles', None, 'Houston']
}
df = pd.DataFrame(data)

# %%
df
# Out:
#       Name   Age         City
# 0    Alice  25.0     New York
# 1      Bob   NaN  Los Angeles
# 2  Charlie  35.0         None
# 3    Diana  40.0      Houston

# %%
df.isnull()
# Out:
#     Name    Age   City
# 0  False  False  False
# 1  False   True  False
# 2  False  False   True
# 3  False  False  False

# %%
df.isna()
# Out:
#     Name    Age   City
# 0  False  False  False
# 1  False   True  False
# 2  False  False   True
# 3  False  False  False

# %%
df_cleaned = df.dropna()
df_cleaned
# Out:
#     Name   Age      City
# 0  Alice  25.0  New York
# 3  Diana  40.0   Houston

# %%
df
# Out:
#       Name   Age         City
# 0    Alice  25.0     New York
# 1      Bob   NaN  Los Angeles
# 2  Charlie  35.0         None
# 3    Diana  40.0      Houston

# %%
df_cleaned = df.dropna(axis=1)
df_cleaned
# Out:
#       Name
# 0    Alice
# 1      Bob
# 2  Charlie
# 3    Diana

# %%
df
# Out:
#       Name   Age         City
# 0    Alice  25.0     New York
# 1      Bob   NaN  Los Angeles
# 2  Charlie  35.0         None
# 3    Diana  40.0      Houston

# %%
df['Age'] = df['Age'].fillna(df['Age'].mean())

# %%
df
# Out:
#       Name        Age         City
# 0    Alice  25.000000     New York
# 1      Bob  33.333333  Los Angeles
# 2  Charlie  35.000000         None
# 3    Diana  40.000000      Houston

# %%
df['City'] = df['City'].fillna('Unknown')

# %%
df
# Out:
#       Name        Age         City
# 0    Alice  25.000000     New York
# 1      Bob  33.333333  Los Angeles
# 2  Charlie  35.000000      Unknown
# 3    Diana  40.000000      Houston

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4 entries, 0 to 3
# Data columns (total 3 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   Name    4 non-null      object
#  1   Age     4 non-null      float64
#  2   City    4 non-null      object
# dtypes: float64(1), object(2)
# memory usage: 228.0+ bytes

# %% [markdown]
# ## Aggregations and Grouping Data

# %%
import pandas as pd
# Sample DataFrame
data = {
    'Category': ['Electronics', 'Electronics', 'Furniture', 'Furniture', 'Apparel'],
    'Product': ['Laptop', 'Mouse', 'Chair', 'Table', 'Shoes'],
    'Sales': [1200, 100, 400, 300, 50]
}
df = pd.DataFrame(data)

# %%
df
# Out:
#       Category Product  Sales
# 0  Electronics  Laptop   1200
# 1  Electronics   Mouse    100
# 2    Furniture   Chair    400
# 3    Furniture   Table    300
# 4      Apparel   Shoes     50

# %%
grouped = df.groupby('Category')['Sales'].sum().reset_index()
grouped
# Out:
#       Category  Sales
# 0      Apparel     50
# 1  Electronics   1300
# 2    Furniture    700

# %%
grouped = df.groupby(['Category', 'Product'])['Sales'].sum()
grouped
# Out:
# Category     Product
# Apparel      Shoes        50
# Electronics  Laptop     1200
#              Mouse       100
# Furniture    Chair       400
#              Table       300
# Name: Sales, dtype: int64

# %%
summary = df.groupby('Category')['Sales'].agg(['sum',  'mean', 'count'])
summary
# Out:
#               sum   mean  count
# Category
# Apparel        50   50.0      1
# Electronics  1300  650.0      2
# Furniture     700  350.0      2
